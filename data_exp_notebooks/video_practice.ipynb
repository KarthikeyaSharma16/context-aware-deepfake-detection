# %%
import os
import pandas as pd
import torch
from torch.utils.data import Dataset
from pytorchvideo.data.encoded_video import EncodedVideo
from transformers import BertTokenizer
from torchvision.transforms import Compose, Lambda, Resize, Normalize, ColorJitter

from torchvision.transforms._transforms_video import (
    CenterCropVideo,
    NormalizeVideo,
)

from pytorchvideo.transforms import (
    ApplyTransformToKey,
    ShortSideScale,
    UniformTemporalSubsample
)
# Out:
# /home/davendra/anaconda3/envs/mlprj/lib/python3.12/site-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /home/davendra/anaconda3/envs/mlprj/lib/python3.12/site-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(

# %% [markdown]
# ### [IGNORE] Initial Transform

# %%
side_size = 256
mean = [0.45, 0.45, 0.45]
std = [0.225, 0.225, 0.225]
crop_size = 256
num_frames = 8
sampling_rate = 8
frames_per_second = 30

# Note that this transform is specific to the slow_R50 model.
transform =  ApplyTransformToKey(
    key="video",
    transform=Compose(
        [
            UniformTemporalSubsample(8),
            Lambda(lambda x: x/255.0),
            NormalizeVideo(mean, std),
            ShortSideScale(
                size=side_size
            ),
            CenterCropVideo(crop_size=(crop_size, crop_size))
        ]
    ),
)

# %% [markdown]
# ### [IGNORE] Sampling frames per clip divided over the video

# %%
video_root = '../train'
index = 0
data = pd.read_csv('../train.csv')

# %%
data.iloc[index]['video_id']+".mp4"
# Out:
# 'KabnUV5luJ8.mp4'

# %%
video_path = os.path.join(video_root, data.iloc[index]['video_id']+".mp4")
label = data.iloc[index]['label']
text = data.iloc[index]['text']

# %%
print(f'video_path: {video_path}')
# Out:
# video_path: ../train/KabnUV5luJ8.mp4

# %%
print(f'label: {label}')
# Out:
# label: 1

# %%
print(f'text: {text}')
# Out:
# text: please name of the software deep fake try putting great thunberg on hitler true it wud be hard to tell dude you are too good cuz she looks like melania trump

# %%
# Load video using PyTorchVideo
video = EncodedVideo.from_path(video_path)

# %%
print(video)
# Out:
# <pytorchvideo.data.encoded_video_pyav.EncodedVideoPyAV object at 0x786f383f5580>

# %%
# Get video duration and calculate the step size for frame sampling
duration = video.duration
step = duration / num_frames
print(f'duration: {duration}')
print(f'step: {step}')
# Out:
# duration: 561152/11025
# step: 70144/11025

# %%
# Sample frames at regular intervals
video_data = []
for i in range(num_frames):
    start_sec = i * step
    end_sec = start_sec + step
    clip = video.get_clip(start_sec=start_sec, end_sec=end_sec)
    video_data.append(transform(clip))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 7
#       5 end_sec = start_sec + step
#       6 clip = video.get_clip(start_sec=start_sec, end_sec=end_sec)
# ----> 7 video_data.append(transform(clip))
#
# KeyboardInterrupt:

# %%
print(len(video_data))
# Out:
# 32

# %%
print(video_data[0]['video'].shape)
# Out:
# torch.Size([3, 1, 256, 256])

# %%
# Stack the sampled frames
# Extract video tensors from each dictionary
video_tensors = [item['video'] for item in video_data]

# Stack video tensors along the frames dimension
stacked_video = torch.stack(video_tensors)

# %%
stacked_video = stacked_video.squeeze(2).permute(1, 0, 2, 3)

# %%
stacked_video.shape
# Out:
# torch.Size([3, 32, 256, 256])

# %%
model = torch.hub.load('facebookresearch/pytorchvideo', 'slow_r50', pretrained=True)
# Out:
# Using cache found in /home/davendra/.cache/torch/hub/facebookresearch_pytorchvideo_main

# %%
input = stacked_video.unsqueeze(0)
input.shape
# Out:
# torch.Size([1, 3, 32, 256, 256])

# %%
pred = model(input)
pred.shape
# Out:
# torch.Size([1, 400])

# %%
feature_extractor = torch.nn.Sequential(*list(model.blocks.children())[:-1])

# %%
pred2 = feature_extractor(input)
pred2.shape
# Out:
# torch.Size([1, 2048, 32, 8, 8])

# %%
pred3 = pred2.permute(0, 2, 3, 4, 1)
pred3.shape
# Out:
# torch.Size([1, 32, 8, 8, 2048])

# %% [markdown]
# ### [IGNORE] Sampling over the entire video

# %%
video_root = '../train'
index = 0
data = pd.read_csv('../train.csv')

# %%
video_path = os.path.join(video_root, data.iloc[index]['video_id']+".mp4")
label = data.iloc[index]['label']
text = data.iloc[index]['text']

# %%
print(f'video_path: {video_path}')
# Out:
# video_path: ../train/KabnUV5luJ8.mp4

# %%
print(f'label: {label}')
# Out:
# label: 1

# %%
print(f'text: {text}')
# Out:
# text: please name of the software deep fake try putting great thunberg on hitler true it wud be hard to tell dude you are too good cuz she looks like melania trump

# %%
clip_duration = (num_frames * sampling_rate)/frames_per_second
start_sec = 0
end_sec = start_sec + clip_duration

# Initialize an EncodedVideo helper class and load the video
video = EncodedVideo.from_path(video_path)

print(video)
# Out:
# <pytorchvideo.data.encoded_video_pyav.EncodedVideoPyAV object at 0x78e3398e71d0>

# %%
# Load the desired clip
video_data = video.get_clip(start_sec=start_sec, end_sec=end_sec)

print(video_data['video'].shape)

# Apply a transform to normalize the video input
video_data = transform(video_data)

print(video_data['video'].shape)
# Out:
# torch.Size([3, 64, 720, 1280])
# torch.Size([3, 8, 256, 256])

# %% [markdown]
# ### Dataset Object

# %%
class DeepFakeDataset(Dataset):
    def __init__(self, video_path_file, text_csv_file, text_transforms=None, video_transforms=None, num_frames=8, sampling_rate=8, frames_per_second=30):
        # self.root = video_root
        self.video_annotation = pd.read_csv(video_path_file)
        self.text_df = pd.read_csv(text_csv_file)
        self.text_transforms = text_transforms
        self.video_transforms = video_transforms
        self.num_frames = num_frames
        self.sampling_rate = sampling_rate
        self.frames_per_second = frames_per_second

    def __len__(self):
        return len(self.video_annotation)

    def __getitem__(self, index):

        video_path = self.video_annotation.iloc[index]['video_path']
        label = self.video_annotation.iloc[index]['label']
        text = self.text_df.iloc[index]['text']

        try:
            # Load video using PyTorchVideo
            video = EncodedVideo.from_path(video_path)

            # Get video duration and calculate the step size for frame sampling
            duration = video.duration
            step = duration / self.num_frames
            print(f'Video length: {duration}')

            # Sample frames at regular intervals
            video_data = []
            for i in range(self.num_frames):
                start_sec = i * step
                end_sec = start_sec + step
                clip = video.get_clip(start_sec=start_sec, end_sec=end_sec)
                print(f'clip shape: {clip['video'].shape}')
                transformed_clip = self.video_transforms(clip['video'])
                print(f'Transformed Clip: {transformed_clip.shape}')
                video_data.append(transformed_clip)

            # Stack the sampled frames
            video_data = torch.stack(video_data)
            # print(video_data)
            print(f'Video_data shape: {video_data.shape}')
            print('--------------------------------------------\n')
            # Stack the sampled frames
            # Extract video tensors from each dictionary
            # video_tensors = [item['video'] for item in video_data]

            # Stack video tensors along the frames dimension
            # video_frames = torch.stack(video_tensors).squeeze(2).permute(1, 0, 2, 3)

            # clip_duration = min((num_frames * sampling_rate) / frames_per_second, video.duration)
            # start_sec = 0
            # clip_duration = video.duration
            # end_sec = start_sec + clip_duration

            # video_data = video.get_clip(start_sec=start_sec, end_sec=end_sec)
            # print(f'video_data shape: {video_data['video'].shape}')

            # # Apply a transform to normalize the video input
            # if self.video_transforms:
            #     video_data = self.video_transforms(video_data['video'])
            #     print(f'Transformed Video data shape: {video_data.shape}')

        except Exception as e:
            print(f'Error Processing video {video_path}: {e}')
            # print(f'Clip Duration: {clip_duration}')
            # print(f'Video Duration: {video.duration}')

        # Apply text transforms
        # if self.text_transforms:
        #     text_data = self.text_transforms(text)
        # else:
        
        text_data = text

        return {
            'video': video_data,
            'text': text_data,
            'label': torch.tensor(label, dtype=torch.long)
        }

# %% [markdown]
# ### Example using Dataset

# %%
# Create instances of text and video transforms
text_transforms = Compose([
    BertTokenizer.from_pretrained('bert-base-uncased'),
    # Add more text transformations as needed
])

side_size = 256
mean = [0.45, 0.45, 0.45]
std = [0.225, 0.225, 0.225]
crop_size = 256
num_frames = 30
sampling_rate = 8
frames_per_second = 30


video_transforms = Compose(
        [
            UniformTemporalSubsample(1),
            Lambda(lambda x: x/255.0),
            NormalizeVideo(mean, std),
            ShortSideScale(
                size=side_size
            ),
            CenterCropVideo(crop_size=(crop_size, crop_size))
        ]
    )

# Create an instance of the dataset

dataset = DeepFakeDataset(
                            video_path_file=video_path_file,
                            text_csv_file=text_csv_file,
                            text_transforms=text_transforms,
                            video_transforms=video_transforms,
                            num_frames=num_frames,
                            sampling_rate=sampling_rate,
                            frames_per_second=frames_per_second
                        )

# %%
# Create a dataloader
batch_size = 8
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=1)

# %%
cnt = 0
video_train=list()
for i, data in enumerate(dataloader):
    video_train.append(data['video'])
    print(f'Finish Batch {i}')
    print('--------------------------------------------\n')
    cnt += 1

    if cnt == 4:
        break
# Out:
# Video length: 349349/7500
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 176896/3675
# clip shape: torch.Size([3, 49, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 49, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 49, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 47, 720, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 241408/1225
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 196, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 196, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 196, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 197, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 196, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 125696/11025
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 376/15
# clip shape: torch.Size([3, 26, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 26, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 25, 720, 1278])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 268288/11025
# clip shape: torch.Size([3, 21, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 21, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 21, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 21, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 21, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 21, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 21, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 21, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 20, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 21, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 19, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 1467904/2205
# clip shape: torch.Size([3, 533, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 533, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 532, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 531, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 354304/11025
# clip shape: torch.Size([3, 33, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 33, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 33, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 32, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 33, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 31, 640, 360])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 33536/735
# clip shape: torch.Size([3, 46, 1280, 720])
# Finish Batch 0
# --------------------------------------------
#
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 46, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 45, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 1661696/11025
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 151, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 150, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 1037056/11025
# clip shape: torch.Size([3, 76, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 76, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 76, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 76, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 76, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 76, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 76, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 76, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 75, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 74, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 647936/11025
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 58, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 58, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 58, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 58, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 58, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 58, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 58, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 58, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 59, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 58, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 18688/525
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 28, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 118528/2205
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 53, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 53, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 53, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 53, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 53, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 53, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 53, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 53, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 54, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 53, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 554752/2205
# clip shape: torch.Size([3, 252, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 252, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 252, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 252, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 252, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 252, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 252, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 252, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 252, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 252, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 251, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 1550336/11025
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 141, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 140, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 332032/11025
# clip shape: torch.Size([3, 31, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Finish Batch 1
# --------------------------------------------
#
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 31, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 31, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 31, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 720, 406])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# ...
# clip shape: torch.Size([3, 49, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 49, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 49, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 49, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 49, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 49, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 49, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 48, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 98816/11025
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 360, 202])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 165632/11025
# clip shape: torch.Size([3, 13, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 12, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 11, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 10496/1225
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 9, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 8, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 35072/1575
# clip shape: torch.Size([3, 23, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 23, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 23, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 23, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 23, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 23, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 23, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 23, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 22, 720, 1280])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 1438208/11025
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 108, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 108, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 108, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 108, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 108, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 108, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 108, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 108, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 109, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 101, 352, 640])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# Video_data shape: torch.Size([30, 3, 1, 256, 256])
# --------------------------------------------
#
# Video length: 107264/3675
# clip shape: torch.Size([3, 30, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])Finish Batch 3
# --------------------------------------------
#
#
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 29, 1280, 720])
# Transformed Clip: torch.Size([3, 1, 256, 256])
# clip shape: torch.Size([3, 30, 1280, 720])

# %%
video_train[0].shape
# Out:
# torch.Size([8, 30, 3, 1, 256, 256])

# %%
video = video_train[0].squeeze(3).permute(0, 2, 1, 3, 4)
video.shape
# Out:
# torch.Size([8, 3, 30, 256, 256])

# %% [markdown]
# ### Experiment with model

# %%
# Choose the `slow_r50` model 
model = torch.hub.load('facebookresearch/pytorchvideo', 'slow_r50', pretrained=True)
# Out:
# Using cache found in /home/davendra/.cache/torch/hub/facebookresearch_pytorchvideo_main

# %%
model.eval()
# Out:
# Net(
#   (blocks): ModuleList(
#     (0): ResNetBasicStem(
#       (conv): Conv3d(3, 64, kernel_size=(1, 7, 7), stride=(1, 2, 2), padding=(0, 3, 3), bias=False)
#       (norm): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#       (pool): MaxPool3d(kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=[0, 1, 1], dilation=1, ceil_mode=False)
#     )
#     (1): ResStage(
#       (res_blocks): ModuleList(
#         (0): ResBlock(
#           (branch1_conv): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (branch1_norm): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_a): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#         (1-2): 2 x ResBlock(
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_a): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#       )
#     )
#     (2): ResStage(
#       (res_blocks): ModuleList(
#         (0): ResBlock(
#           (branch1_conv): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#           (branch1_norm): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_a): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#         (1-3): 3 x ResBlock(
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_a): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#       )
#     )
#     (3): ResStage(
#       (res_blocks): ModuleList(
#         (0): ResBlock(
#           (branch1_conv): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#           (branch1_norm): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(512, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             (norm_a): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#         (1-5): 5 x ResBlock(
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             (norm_a): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#       )
#     )
#     (4): ResStage(
#       (res_blocks): ModuleList(
#         (0): ResBlock(
#           (branch1_conv): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#           (branch1_norm): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(1024, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             (norm_a): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#         (1-2): 2 x ResBlock(
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             (norm_a): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#       )
#     )
#     (5): ResNetBasicHead(
#       (pool): AvgPool3d(kernel_size=(8, 7, 7), stride=(1, 1, 1), padding=(0, 0, 0))
#       (dropout): Dropout(p=0.5, inplace=False)
#       (proj): Linear(in_features=2048, out_features=400, bias=True)
#       (output_pool): AdaptiveAvgPool3d(output_size=1)
#     )
#   )
# )

# %%
print(model)
# Out:
# Net(
#   (blocks): ModuleList(
#     (0): ResNetBasicStem(
#       (conv): Conv3d(3, 64, kernel_size=(1, 7, 7), stride=(1, 2, 2), padding=(0, 3, 3), bias=False)
#       (norm): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): ReLU()
#       (pool): MaxPool3d(kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=[0, 1, 1], dilation=1, ceil_mode=False)
#     )
#     (1): ResStage(
#       (res_blocks): ModuleList(
#         (0): ResBlock(
#           (branch1_conv): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#           (branch1_norm): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_a): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#         (1-2): 2 x ResBlock(
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_a): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#       )
#     )
#     (2): ResStage(
#       (res_blocks): ModuleList(
#         (0): ResBlock(
#           (branch1_conv): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#           (branch1_norm): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(256, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_a): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#         (1-3): 3 x ResBlock(
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_a): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#       )
#     )
#     (3): ResStage(
#       (res_blocks): ModuleList(
#         (0): ResBlock(
#           (branch1_conv): Conv3d(512, 1024, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#           (branch1_norm): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(512, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             (norm_a): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#         (1-5): 5 x ResBlock(
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             (norm_a): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#       )
#     )
#     (4): ResStage(
#       (res_blocks): ModuleList(
#         (0): ResBlock(
#           (branch1_conv): Conv3d(1024, 2048, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#           (branch1_norm): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(1024, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             (norm_a): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#         (1-2): 2 x ResBlock(
#           (branch2): BottleneckBlock(
#             (conv_a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             (norm_a): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_a): ReLU()
#             (conv_b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#             (norm_b): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act_b): ReLU()
#             (conv_c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#             (norm_c): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (activation): ReLU()
#         )
#       )
#     )
#     (5): ResNetBasicHead(
#       (pool): AvgPool3d(kernel_size=(8, 7, 7), stride=(1, 1, 1), padding=(0, 0, 0))
#       (dropout): Dropout(p=0.5, inplace=False)
#       (proj): Linear(in_features=2048, out_features=400, bias=True)
#       (output_pool): AdaptiveAvgPool3d(output_size=1)
#     )
#   )
# )

# %%
# "Remove" Classifier Layer
model.blocks[5] = torch.nn.Identity()

# %%
# dummy input
dummy_input = torch.rand(1, 3, 30, 256, 256)
output = model(dummy_input)
print(output.shape)
# Out:
# torch.Size([1, 768, 30, 8, 8])

# %%
conv = torch.nn.Conv3d(2048, 768, kernel_size=(1, 1, 1), stride=(1, 1, 1), padding=(0, 0, 0))

output = conv(output)
output.shape

# %%
output = output.reshape(1, 768, -1)
output = output.permute(0,2,1)
output.shape
# Out:
# torch.Size([1, 512, 768])

# %%
import sys
import os

# Add the parent directory to sys.path to access the `model` package
parent_dir = os.path.dirname('../model')
sys.path.insert(0, parent_dir)

from model.resnet_50 import ModifiedResnet3D as resnet

model = resnet()
# Out:
# Using cache found in /home/davendra/.cache/torch/hub/facebookresearch_pytorchvideo_main

# %%
dummy = torch.rand(1, 3, 16, 256, 256)

# %%
out = model(dummy)
out.shape
# Out:
# torch.Size([1, 768, 16, 8, 8])

# %%
out = out.reshape(1, 768, -1)
out = out.permute(0,2,1)
out.shape
# Out:
# torch.Size([1, 1024, 768])
