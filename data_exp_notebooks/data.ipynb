# %%
import os
import shutil
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from wordcloud import WordCloud
from textblob import TextBlob
from moviepy.editor import VideoFileClip
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ### Collect Data

# %%
neg_vids_dir = '/home/davendra/ml-prj/deepfake_extractions/videos/negative'
pos_vids_dir = '/home/davendra/ml-prj/deepfake_extractions/videos/positive'


neg_train_csv = '/home/davendra/ml-prj/context-aware-deepfake-detection/negative/training.csv'
neg_val_csv = '/home/davendra/ml-prj/context-aware-deepfake-detection/negative/validation.csv'
neg_test_csv = '/home/davendra/ml-prj/context-aware-deepfake-detection/negative/test.csv'

pos_train_csv = '/home/davendra/ml-prj/context-aware-deepfake-detection/positive/training.csv'
pos_val_csv = '/home/davendra/ml-prj/context-aware-deepfake-detection/positive/validation.csv'
pos_test_csv = '/home/davendra/ml-prj/context-aware-deepfake-detection/positive/test.csv'

train_dir = '/home/davendra/ml-prj/context-aware-deepfake-detection/train'
val_dir = '/home/davendra/ml-prj/context-aware-deepfake-detection/val'
test_dir = '/home/davendra/ml-prj/context-aware-deepfake-detection/test'

# %%
# Collect all data into dataframes

# Positive
pos_train_df = pd.read_csv(pos_train_csv).drop_duplicates('video_id', keep='first')
pos_val_df = pd.read_csv(pos_val_csv).drop_duplicates('video_id', keep='first')
pos_test_df = pd.read_csv(pos_test_csv).drop_duplicates('video_id', keep='first')

# Negative
neg_train_df = pd.read_csv(neg_train_csv).drop_duplicates('video_id', keep='first')
neg_val_df = pd.read_csv(neg_val_csv).drop_duplicates('video_id', keep='first')
neg_test_df = pd.read_csv(neg_test_csv).drop_duplicates('video_id', keep='first')

# %%
def add_video_durations(df, source_dir):
    """
    Appends the duration of video files to the DataFrame.

    Args:
    df (pd.DataFrame): DataFrame containing video metadata.
    source_dir (str): The directory path where video files are stored.

    Returns:
    pd.DataFrame: Updated DataFrame with a new column for video duration.
    """
    
    # Helper function to get the duration of a single video
    def get_duration(video_id):
        file_path = f"{source_dir}/{video_id}.mp4"
        try:
            with VideoFileClip(file_path) as clip:
                return clip.duration
        except Exception as e:
            print(f"Could not process {file_path}: {e}")
            return None
    
    # Applying the function to each row to calculate durations
    df['duration'] = df['video_id'].apply(get_duration)
    
    return df

# %%
pos_train_df = add_video_durations(pos_train_df, pos_vids_dir)
pos_val_df = add_video_durations(pos_val_df, pos_vids_dir)
pos_test_df = add_video_durations(pos_test_df, pos_vids_dir)

neg_train_df = add_video_durations(neg_train_df, neg_vids_dir)
neg_val_df = add_video_durations(neg_val_df, neg_vids_dir)
neg_test_df = add_video_durations(neg_test_df, neg_vids_dir)

# %% [markdown]
# ### Eliminate Videos longer than 60 seconds

# %%
print(f'Len of pos_train_df: {len(pos_train_df)}')
print(f'Len of pos_val_df: {len(pos_val_df)}')
print(f'Len of pos_test_df: {len(pos_test_df)}')

print(f'Len of neg_train_df: {len(neg_train_df)}')
print(f'Len of neg_val_df: {len(neg_val_df)}')
print(f'Len of neg_test_df: {len(neg_test_df)}')
# Out:
# Len of pos_train_df: 303
# Len of pos_val_df: 43
# Len of pos_test_df: 88
# Len of neg_train_df: 317
# Len of neg_val_df: 46
# Len of neg_test_df: 93

# %%
pos_train_df = pos_train_df.query('duration <= 60')  
pos_val_df = pos_val_df.query('duration <= 60')  
pos_test_df = pos_test_df.query('duration <= 60')  

neg_train_df = neg_train_df.query('duration <= 60')  
neg_val_df = neg_val_df.query('duration <= 60')  
neg_test_df = neg_test_df.query('duration <= 60')

# %%
print(f'Len of pos_train_df: {len(pos_train_df)}')
print(f'Len of pos_val_df: {len(pos_val_df)}')
print(f'Len of pos_test_df: {len(pos_test_df)}')

print(f'Len of neg_train_df: {len(neg_train_df)}')
print(f'Len of neg_val_df: {len(neg_val_df)}')
print(f'Len of neg_test_df: {len(neg_test_df)}')
# Out:
# Len of pos_train_df: 176
# Len of pos_val_df: 26
# Len of pos_test_df: 46
# Len of neg_train_df: 195
# Len of neg_val_df: 26
# Len of neg_test_df: 51

# %% [markdown]
# ### Display Negative Data

# %%
display(neg_train_df)
print(f'Size of Negative Train Data: {len(neg_train_df)}')
# Out:
#         video_id                                              title  \
# 0    NIAnOmqK2k0  Yikes! Joe Biden On Why He Was So Irresponsibl...
# 3    PNKWjqW8kvI  Biden Gets Confused (Again): "Middle Class Did...
# 4    iKKRU3ALjb0        Republicans want a national ban on abortion
# 5    N-fELwFvM64        Haley ends Republican presidential campaign
# 6    r94vuvwUSkY                                         What? Meme
# ..           ...                                                ...
# 314  TLw64MCra3U   Rishi Sunak frees up millions of GP appointments
# 315  liII_ikKCIo                                       Qui menace ?
# 316  yyaEuBNhpqY  Courteney Cox Wants Zac Efron as a Love Intere...
# 318  rs3vQ49mfrY  "I'm IGN" #KeanuReeves #johnwick #redcarpet #m...
# 320  yJp5bEEO8uo                    Elon Musk warns as about AI💫🔥👌🏻
#
#                                            description  \
# 0                                                  NaN
# 3                             Comments made on 4/17/24
# 4    Follow Joe!Joe’s Twitter: https://twitter.com/...
# 5    Former U.N. ambassador Nikki Haley ended her b...
# 6                                         Sub and Like
# ..                                                 ...
# 314  9 in 10 pharmacies across England are now offe...
# 315                                                NaN
# 316  SUBSCRIBE: https://ellen.tv/3D6Sewq The place ...
# 318                                                NaN
# 320                                                NaN
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=NIAnOmqK2k0
# 3    https://www.youtube.com/watch?v=PNKWjqW8kvI
# 4    https://www.youtube.com/watch?v=iKKRU3ALjb0
# 5    https://www.youtube.com/watch?v=N-fELwFvM64
# 6    https://www.youtube.com/watch?v=r94vuvwUSkY
# ..                                           ...
# 314  https://www.youtube.com/watch?v=TLw64MCra3U
# 315  https://www.youtube.com/watch?v=liII_ikKCIo
# 316  https://www.youtube.com/watch?v=yyaEuBNhpqY
# 318  https://www.youtube.com/watch?v=rs3vQ49mfrY
# 320  https://www.youtube.com/watch?v=yJp5bEEO8uo
#
#                                               comments  label  duration
# 0    idk should I feel sad or mad at him<sep>&quot;...      0     15.05
# 3    What?<sep>This is funny but dueable.    All th...      0      8.71
# 4    FJB.<br>He&#39;s to old and his brain doesn&#3...      0     15.23
# 5    Your voice is horrible.😂🎉<sep>That congratulat...      0     44.77
# 6    Lol<sep>Is that Russel westbrook?<sep>6 sec ad...      0      5.57
# ..                                                 ...    ...       ...
# 314  If I need to see the GP, it&#39;s because it&#...      0     37.96
# 315  P. A. F<sep>P. A. F<sep>Monsieur Macron pour ê...      0     59.58
# 316  I saw a short video of Ellen that was with Nev...      0     34.85
# 318  Tan bello y humilde ❤<sep>They can shoot their...      0     16.90
# 320  How is Ai possibly more dangerous than nukes.....      0     19.81
#
# [195 rows x 7 columns]
# Size of Negative Train Data: 195

# %%
display(neg_val_df)
print(f'Size of Negative Val Data: {len(neg_val_df)}')
# Out:
#        video_id                                              title  \
# 2   xzm_IlrpK_Y  ראש הממשלה נתניהו במערך 9900: "אנחנו אומרים למ...
# 3   R1DaTvQXwpY  Impeached DHS Sec. Alejandro Mayorkas: The sou...
# 5   _I9vGD4j1_U  BREAKING: Joe Biden Says One Of The Classified...
# 6   s_zva6pf3oA          Donald Trump Predicts his Victory in 1988
# 8   YIWdxO2J-Tw  The Top 5 Moments of Taylor Swift’s Life 🖐 #sh...
# 10  527-1MrJYUE  Laxmi Raai 😍 Spotted at Kromakay Salon in Juhu...
# 15  DKB4Mf5PVFY  Trump being a sigma… #alphamale #masculinity #...
# 16  wswxrDiSiHI  Obama's Quick Response To Sarcastic Republican...
# 17  whnY9-ugr2w  Trump sells Bibles after years of touting his ...
# 18  t7xDb82TqiI           Nvidia's Ceo On Greatness | Jensen Huang
# 20  TghKVxflpYo             Donald Trump Impression Of Joe Biden 🤣
# 21  s6Wjo9Civ_k  Joe Biden, reading from his giant teleprompter...
# 22  LYZTKTRLZ2U  😂 Rowan Atkinson funny moments at Top Gear BBC...
# 23  TivAwezqug4                            ANUSHKA SHARMA AUDITION
# 25  1iBI3uW6lJA  I made this video last night at 12:30am, but m...
# 26  vxOzffnZ-Ds  Selena Gomez on Being a Fashion Newbie | Met G...
# 28  p1WD_rDHsFc     Selena Gomez Goes Behind the Scenes With Vogue
# 29  xudVnd6DTSQ                        Democracy is on the ballot.
# 30  B4K_OfMnTD0  Kennedy family endorses Pres. Biden in 2024 el...
# 33  caqsDWJ-q8c                      Snoop Dogg was looking for me
# 35  PgJ_R1gjwTs  Akshay Kumar CAN'T SPELL Jacqueline's Name!🤣 F...
# 39  F8ajpQV-Fb4                 Only have Chico's to end the night
# 42  3KgGuOYUylE                       Elon Musk ROASTS Joe Biden 🤣
# 43  3vO1eXoRvUg            Norman Finkelstein : Reason of Iraq war
# 44  tZOT-HzZy-Y  Moms Leaving their Kids Overnight #momlife #mo...
# 45  1nW1S46_B-Y  Jeff bezos motivation #mymotivation #shortsvir...
#
#                                           description  \
# 2   ראש הממשלה בנימין נתניהו ביקר היום (ג׳) במערך ...
# 3                                                 NaN
# 5                                                 NaN
# 6   💰 Welcome to WealthTeachers – your hub for lon...
# 8   SUBSCRIBE: https://ellen.tv/3D6Sewq The place ...
# 10                                                NaN
# 15                                                NaN
# 16  Watch Barack Obama's response when Republicans...
# 17  Former president Donald Trump trumpeted his lo...
# 18  Original Video: https://www.youtube.com/watch?...
# 20                                                NaN
# 21                                                NaN
# 22  The Best Funny Moment you absolutely have to s...
�❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤...      0     55.64
# 54  Americans.... what a joke 😢😢😢😢<sep>Putin looks...      0     34.25
# 56                                                NaN      0     49.09
# 57  Very nice short video ellen<sep>Omg where can ...      0     59.56
# 59                                                NaN      0     51.94
# 60  There is no israeal only palestine<sep>Shame o...      0     43.86
# 61  So because there’s a lot of killers that makes...      0     23.96
# 62  Oooh la laaaaaa!  lol<sep>Sully didn’t underst...      0      6.92
# 66  Says the hypocrite crook.  😂😂😂😂<sep>Well, we d...      0     38.01
# 68  Putin doing Putin things<sep>LET IT GO!!!!!!!<...      0     33.11
# 69  Jay shree ram<sep>Kya bola ???<sep>Zbrdast<sep...      0     16.37
# 70  Never miss out on AI trends that could quickly...      0     58.89
# 71  the more i watch the more understanding<sep>He...      0     54.52
# 72  Brilliant...<br>He is perfect blend of intelli...      0     28.00
# 75  can&#39;t do his job right<sep>Keep Working an...      0     52.64
# 77  Llist Mysore cafe in stock market our people t...      0     24.64
# 81  27 times<sep>Two face<sep>I like him<sep>The b...      0     59.95
# 83  “Not this year” bro sounded like batman<sep>Tr...      0     23.96
# 90  Like and share the video if you love President...      0     39.33
# 91  Youtube, why are you paranoid of my comments, ...      0     24.20
# Size of Negative Test Data: 51

# %% [markdown]
# ### Display Positive Data

# %%
display(pos_train_df)
print(f'Size of Positive Train Data: {len(pos_train_df)}')
# Out:
#         video_id                                              title  \
# 0    KabnUV5luJ8     Cersei Lannister is Melania Trump [ Deepfake ]
# 2    6aSoP0mDM0g         Obama ACTUALLY Does the Obamehameha (REAL)
# 3    H_RFyF-tgZ4  DEEPFAKE | THOR Selling Phones in INDIA | Aven...
# 4    E_hjqpXgUO0   Donald Trump gets all Fat and Sassy [ Deepfake ]
# 5    pQuS5Pmrtnk     Mark Zuckerberg flirting with Trump [Deepfake]
# ..           ...                                                ...
# 298  B68GxCrs5rI  Problem Сhild / Macaulay Culkin (DeepFake) Tik...
# 299  OF2Hrq2aK5k             Presidential Tales: Kidnappers Shoes !
# 300  UkjmTzUZbdQ                      Flying Cars [RIFE AI Slow-Mo]
# 301  jxxzi4es0Ko  Ace Ventura / Ben Stiller (DeepFake) TikTok #S...
# 302  MQ8DQgAwXew              Jay Leno as Sean Hannity [ Deepfake ]
#
#                                            description  \
# 0    Enjoy :) And PLEASE Like & Subscribe if you wa...
# 2    Sleepy Joe's Biden Blast is one thing.Big Mike...
# 3    Deepfake | Thor at Mobile Shop in India 😂😂What...
# 4    ENJOY!Check out our community forums:https://o...
# 5    New deepfake featuring Mark Zuckerberg and Don...
# ..                                                 ...
# 298  Do not click 😎 https://www.youtube.com/c/AnyFa...
# 299  Presidential Tales: Biden, Trump, Clinton, Oba...
# 300  This a test of new neural network called RIFE,...
# 301  Do not click 😎  https://www.youtube.com/c/AnyF...
# 302  Enjoy :) And PLEASE Like & Subscribe if you wa...
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=KabnUV5luJ8
# 2    https://www.youtube.com/watch?v=6aSoP0mDM0g
# 3    https://www.youtube.com/watch?v=H_RFyF-tgZ4
# 4    https://www.youtube.com/watch?v=E_hjqpXgUO0
# 5    https://www.youtube.com/watch?v=pQuS5Pmrtnk
# ..                                           ...
# 298  https://www.youtube.com/watch?v=B68GxCrs5rI
# 299  https://www.youtube.com/watch?v=OF2Hrq2aK5k
# 300  https://www.youtube.com/watch?v=UkjmTzUZbdQ
# 301  https://www.youtube.com/watch?v=jxxzi4es0Ko
# 302  https://www.youtube.com/watch?v=MQ8DQgAwXew
#
#                                               comments  label  duration
# 0    Please name of the software ?<sep>Deep fake<se...      1     50.90
# 2    Now we need Trumps card to block the attacks a...      1     22.27
# 3    How do you guys not have millions of subscribe...      1     36.13
# 4              Same. 😒<sep>Lol the way the head moves.      1     10.38
# 5    <a href="https://shutr.bz/3H7OcGG">https://shu...      1     38.45
# ..                                                 ...    ...       ...
# 298                                                NaN      1     23.27
# 299  Funny! 👍<sep>That Blank expression of Biden af...      1     21.73
# 300  <a href="https://shutr.bz/3H7OcGG">https://shu...      1     30.30
# 301                                                NaN      1     48.65
# 302  OMFG...😂<sep>Now he looks like John Goodman lo...      1     49.30
#
# [176 rows x 7 columns]
# Size of Positive Train Data: 176

# %%
display(pos_val_df)
print(f'Size of Positive Val Data: {len(pos_val_df)}')
# Out:
#        video_id                                              title  \
# 1   AcQdS9M7P5I                Ghost Caught On Traffic CCTV Camera
# 2   9J54CMpQO1A            Presidential Tales: My Wife Birthday...
# 4   lDR2lmCO6iM                Scarlett Johansson eating Spaghetti
# 8   4Qwyb-JZQuA  Men in Black / Kevin Hart (DeepFake) TikTok #S...
# 10  m6teLPZLMyI  C3PO's looks at his REAL FRIENDS before he die...
# 11  vyFzuGF_kmM  Kevin Spacey is back to acting - as Donald Tru...
# 12  jbvlVo8WLOU    Aladdin / Amber Heard (DeepFake) TikTok #Shorts
# 14  320yMfXjHd4      Presidential Tales:  I Accidentally Swallowed
# 15  htYo_eAcwHQ           Presidential Tales: Pregnant Barbie Doll
# 17  F4DrMNC23uw  The Voyage of Doctor Dolittle / Leonardo DiCap...
# 19  tOkfisapoRo           Presidential Tales: Unspeakable things !
# 20  yRH1lncs_vg                    Pewdiepie is Grandpa [DeepFake]
# 23  -q1-uOrWrpM  President Donald Bean talks about Easter sadne...
# 24  UPkhE4yB3Ik                Big Ed but its PewDiePie [Deepfake]
# 26  SMfaJPTsUy0          When You Get A Haircut In GTA San Andreas
# 27  ewRQ_GiyKNQ      Elon Musk uses A.I. Donald Trump voice | FAKE
# 30  cEefWGI9EM0                          Phobia Of Getting Married
# 31  4TM6h4BO7L0  Take That Jack! Joe Biden Beat Boxes! ( Ft. Ev...
# 34  e_0KdeCMoR0             Presidential Tales: Microsoft Office !
# 36  aVNfExpzMbI       Presidential Tales: My Printer Playing Music
# 37  Zm2g0RJKWvc    Will Smith eating Spaghetti and Meatballs again
# 37  https://www.youtube.com/watch?v=Zm2g0RJKWvc
# 38  https://www.youtube.com/watch?v=6PoF9Qec52w
# 39  https://www.youtube.com/watch?v=_o6eHdkcwwQ
# 40  https://www.youtube.com/watch?v=9_fxI4B3GM0
# 41  https://www.youtube.com/watch?v=IHrlx5Xfwa8
# 42  https://www.youtube.com/watch?v=6EtRrHfeHKc
#
#                                              comments  label  duration
# 1   Very cool.<sep>Omg is this really may I take t...      1     30.86
# 2   So, I bought her nothing 😂😂😂😂😂<sep>So fake... ...      1     24.50
# 4   She is beautiful and saucy! 😃❤<sep>everyone mu...      1     39.82
# 8                                                 NaN      1     24.68
# 10  If this doesn&#39;t make you feel something in...      1     16.04
# 11  Who is that lol<sep>He looks Asian now lmao<se...      1     57.40
# 12                                                NaN      1     23.41
# 14  A script to die for !<sep>it was actualy funny...      1     25.63
# 15  So many people hate GW Bush, but i would reall...      1     25.38
# 17                                                NaN      1     11.98
# 19  Smh lol 😅😅😅😅<sep>Can anyone explain the salad ...      1     28.00
# 20  <a href="https://shutr.bz/3H7OcGG">https://shu...      1      8.61
# 23  هههههههخ<sep>This makes for some great enterta...      1     40.50
# 24  To the person who made this, you are awesome 😎...      1     31.25
# 26  Me when I was 12 wondering what I&#39;d look l...      1     30.09
# 27  DONALD TRUMP PRESIDENT EEUU RUMBO A LA PRESIDE...      1     40.43
# 30  Can&#39;t wait for these 2 traitors to be pros...      1     24.80
# 31  Wonderful rap 👏👌 take that jack<sep>Awasome!<s...      1     20.22
# 34  我真的聽不懂英文<sep>The fake lines from AI are too re...      1     23.48
# 36  GW liked the biden joke 😂😂<sep>The secret serv...      1     32.67
# 37  <a href="https://www.youtube.com/watch?v=Zm2g0...      1     52.87
# 38  <a href="https://shutr.bz/3H7OcGG">https://shu...      1     17.60
# 39                                                NaN      1     14.47
# 40  The kid looks like actor Peter Gerety from Sne...      1     49.06
# 41  Bro kept trying to turn into a helicoprion<sep...      1     49.62
# 42  <a href="https://shutr.bz/3H7OcGG">https://shu...      1      9.82
# Size of Positive Val Data: 26

# %%
display(pos_test_df)
print(f'Size of Positive Test Data: {len(pos_test_df)}')
# Out:
#        video_id                                              title  \
# 1   Xj0vm2n90SU  The Hangover /Chris Evans (DeepFake) TikTok #S...
# 2   0M7XvqtWUWc  Interview with the Vampire / Robert Pattinson ...
# 3   8eMnD0QSZqs  Donald Trump with Mike "Kathy Griffin" Pence [...
# 4   Hli_IGInsZc                                   Terminator T-800
# 5   mC-lE6_MrfI      Deepfake | Sanjay Dutt as Arnold | Terminator
# 6   VOBulYr3swc  Chloe from Detroit Become Human talks about Cr...
# 7   9utpya9UZwU           Mr Beast and PewDiePie at the playground
# 8   Ktg3uLCcRX8  Michael Jackson Demo  (private video) [ Deepfa...
# 12  a15h8twMfqs        Dr. Phil sings Dama Da Ne (Baka Mitai Meme)
# 13  qCVJprRg3xI             Presidential Tales: Living In China...
# 14  zvZHVNLznNI        Justin Timberlake (DeepFake) TikTok #Shorts
# 15  tFtw4ukISLk             Lionel Messi (DeepFake) TikTok #Shorts
# 44  This is amazing.<sep>I understand. The gibberi...      1     34.02
# 47  <a href="https://www.youtube.com/watch?v=Q0K2G...      1     35.81
# 49  I love this epic cross over.<br>The Corn Pop a...      1     56.40
# 50                                                NaN      1     12.93
# 51  It actually looks like something i’d dream abo...      1     32.81
# 52                                                NaN      1     18.74
# 55  &quot;Life is like a pe-&quot; 😂😂😂😂<sep>Gorge ...      1     45.93
# 59  I receive communion in my home once a week and...      1     31.51
# 62  😂😂😂😂😂😂<sep>HEY CAN  YOU COMBINE THIS VIDEO WIT...      1     48.37
# 63                                                NaN      1     14.65
# 64  An ai video where they actually try to eta the...      1     40.01
# 65  Whoa, he&#39;s very chinese here 🤣🤣😅<sep>Suppo...      1     32.60
# 66  The way this works is that you put a name into...      1     38.41
# 70  Footage of Ed&#39;s trip to The Imperial City<...      1     17.14
# 72  Dat zoom tho<br><br>Trump in Oblivion link in ...      1      3.88
# 73                   👍<sep>HELLO BRO AFTER 1 YEAR 😎😂😀      1     29.74
# 78                                                NaN      1     13.91
# 80  The shark just want to say hi<sep>excuse me ，I...      1     20.02
# 81  ❤ these vids<sep>What&#39;s the difference bet...      1     34.85
# 82                                                NaN      1     14.00
# 86  <a href="https://shutr.bz/3H7OcGG">https://shu...      1     59.98
# Size of Positive Test Data: 46

# %% [markdown]
# ### Some Cleaning Functions

# %% [markdown]
# Cleaning Text
# 1. Remove Punctuations and stopwords
# 2. Remove <seps>
# 3. Remove HTML tags and url
# 4. Demojize
# 5. Expand abbreviations and contractions (use python contraction library)
# 6. Expand colloquialisms
# 7. Translate Foreign Languages to english
# 8. Convert to Lower case
# 9. Fix grammatical errors
# 10. Lemmatization

# %%
import re
import string
import emoji

def clean_text(text):
    # Convert input to string
    text = str(text)
    
    # Remove <sep> tags
    text = re.sub(r'<sep>', ' ', text)
    
    # Remove HTML tags
    text = re.sub(r'<[^>]*>', ' ', text)
    
    # Remove URLs
    text = re.sub(r'http\S+', ' ', text)
    
    # Remove punctuation marks
    text = text.translate(str.maketrans(' ', ' ', string.punctuation))
    
    # Remove emojis
    text = emoji.replace_emoji(text, replace='')
    
    # Convert text to lowercase
    text = text.lower()
    
    # Remove extra whitespace
    text = text.strip()
    text = re.sub(r'\s+', ' ', text)
    
    return text

# %%
text = '<sep>Lol the way the head moves'
clean_text(text)
# Out:
# 'lol the way the head moves'

# %% [markdown]
# ### Youtube Scraping

# %%
# api_key = 'AIzaSyDyCuxE5dBSUkUypRMU4OojLn__g7-Wujo'
# videoID = ''
# get_comments(apikey=api_key, videoID=videoID)

# %%
from googleapiclient.discovery import build

def get_comments(apikey=None, videoID=None):
    # Replace with your actual API key
    API_KEY = apikey

    # Create a YouTube Data API client
    youtube = build('youtube', 'v3', developerKey=API_KEY)

    # Replace with the ID of the video you want to retrieve comments from
    VIDEO_ID = videoID

    # Retrieve the comments for the video
    response = youtube.commentThreads().list(
        part='snippet',
        videoId=VIDEO_ID,
        textFormat='plainText'
    ).execute()

    # Process the comments
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        author = comment['authorDisplayName']
        text = comment['textDisplay']
        print(f'Author: {author}')
        print(f'Comment: {text}')
        print('---')

    # Check if there are more pages of comments
    while 'nextPageToken' in response:
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=VIDEO_ID,
            pageToken=response['nextPageToken'],
            textFormat='plainText'
        ).execute()

        # Process the comments on the next page
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            author = comment['authorDisplayName']
            text = comment['textDisplay']
            print(f'Author: {author}')
            print(f'Comment: {text}')
            print('---')

# %% [markdown]
# ### Cleaning Positives

# %%
# Create a new DataFrame with the cleaned text for positive
cleaned_pos_train_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])
cleaned_pos_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])
cleand_pos_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])

# %%
cleaned_pos_train_df['video_id'] = pos_train_df['video_id']
cleaned_pos_train_df['url'] = pos_train_df['url']
cleaned_pos_train_df['label'] = pos_train_df['label']
cleaned_pos_train_df['duration'] = pos_train_df['duration']
cleaned_pos_train_df['title'] = pos_train_df['title'].apply(clean_text)
cleaned_pos_train_df['description'] = pos_train_df['description'].apply(clean_text)
cleaned_pos_train_df['comments'] = pos_train_df['comments'].apply(clean_text)

# %%
display(cleaned_pos_train_df)
print(f'Size of Cleaned Positive Train Data: {len(cleaned_pos_train_df)}')
# Out:
#         video_id                                              title  \
# 0    KabnUV5luJ8         cersei lannister is melania trump deepfake
# 2    6aSoP0mDM0g           obama actually does the obamehameha real
# 3    H_RFyF-tgZ4     deepfake thor selling phones in india avengers
# 4    E_hjqpXgUO0       donald trump gets all fat and sassy deepfake
# 5    pQuS5Pmrtnk       mark zuckerberg flirting with trump deepfake
# ..           ...                                                ...
# 298  B68GxCrs5rI  problem сhild macaulay culkin deepfake tiktok ...
# 299  OF2Hrq2aK5k                presidential tales kidnappers shoes
# 300  UkjmTzUZbdQ                         flying cars rife ai slowmo
# 301  jxxzi4es0Ko     ace ventura ben stiller deepfake tiktok shorts
# 302  MQ8DQgAwXew                  jay leno as sean hannity deepfake
#
#                                            description  \
# 0    enjoy and please like subscribe if you want to...
# 2    sleepy joes biden blast is one thingbig mikes ...
# 3    deepfake thor at mobile shop in india what if ...
# 4    enjoycheck out our community forums helping th...
# 5    new deepfake featuring mark zuckerberg and don...
# ..                                                 ...
# 298  do not click a help of neural networks anyone ...
# 299  presidential tales biden trump clinton obama p...
# 300  this a test of new neural network called rife ...
# 301  do not click a help of neural networks anyone ...
# 302  enjoy and please like subscribe if you want to...
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=KabnUV5luJ8
# 2    https://www.youtube.com/watch?v=6aSoP0mDM0g
# 3    https://www.youtube.com/watch?v=H_RFyF-tgZ4
# 4    https://www.youtube.com/watch?v=E_hjqpXgUO0
# 5    https://www.youtube.com/watch?v=pQuS5Pmrtnk
# ..                                           ...
# 298  https://www.youtube.com/watch?v=B68GxCrs5rI
# 299  https://www.youtube.com/watch?v=OF2Hrq2aK5k
# 300  https://www.youtube.com/watch?v=UkjmTzUZbdQ
# 301  https://www.youtube.com/watch?v=jxxzi4es0Ko
# 302  https://www.youtube.com/watch?v=MQ8DQgAwXew
#
#                                               comments  label  duration
# 0    please name of the software deep fake try putt...      1     50.90
# 2    now we need trumps card to block the attacks a...      1     22.27
# 3    how do you guys not have millions of subscribe...      1     36.13
# 4                      same lol the way the head moves      1     10.38
# 5    unlock the power of stock footage today nathan...      1     38.45
# ..                                                 ...    ...       ...
# 298                                                nan      1     23.27
# 299  funny that blank expression of biden after the...      1     21.73
# 300  unlock the power of stock footage today cool c...      1     30.30
# 301                                                nan      1     48.65
# 302  omfg now he looks like john goodman lol hilari...      1     49.30
#
# [176 rows x 7 columns]
# Size of Cleaned Positive Train Data: 176

# %%
cleaned_pos_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])
cleaned_pos_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])
cleaned_pos_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])

cleaned_pos_val_df['video_id'] = pos_val_df['video_id']
cleaned_pos_val_df['url'] = pos_val_df['url']
cleaned_pos_val_df['label'] = pos_val_df['label']
cleaned_pos_val_df['duration'] = pos_val_df['duration']
cleaned_pos_val_df['title'] = pos_val_df['title'].apply(clean_text)
cleaned_pos_val_df['description'] = pos_val_df['description'].apply(clean_text)
cleaned_pos_val_df['comments'] = pos_val_df['comments'].apply(clean_text)

# %%
display(cleaned_pos_val_df)
print(f'Size of Cleaned Positive Val Data: {len(cleaned_pos_val_df)}')
# Out:
#        video_id                                              title  \
# 1   AcQdS9M7P5I                ghost caught on traffic cctv camera
# 2   9J54CMpQO1A                presidential tales my wife birthday
# 4   lDR2lmCO6iM                scarlett johansson eating spaghetti
# 8   4Qwyb-JZQuA     men in black kevin hart deepfake tiktok shorts
# 10  m6teLPZLMyI  c3pos looks at his real friends before he dies...
# 11  vyFzuGF_kmM  kevin spacey is back to acting as donald trump...
# 12  jbvlVo8WLOU         aladdin amber heard deepfake tiktok shorts
# 14  320yMfXjHd4        presidential tales i accidentally swallowed
# 15  htYo_eAcwHQ            presidential tales pregnant barbie doll
# 17  F4DrMNC23uw  the voyage of doctor dolittle leonardo dicapri...
# 19  tOkfisapoRo              presidential tales unspeakable things
# 20  yRH1lncs_vg                      pewdiepie is grandpa deepfake
# 23  -q1-uOrWrpM  president donald bean talks about easter sadne...
# 24  UPkhE4yB3Ik                  big ed but its pewdiepie deepfake
# 26  SMfaJPTsUy0          when you get a haircut in gta san andreas
# 27  ewRQ_GiyKNQ          elon musk uses ai donald trump voice fake
# 30  cEefWGI9EM0                          phobia of getting married
# 31  4TM6h4BO7L0  take that jack joe biden beat boxes ft evan gr...
# 34  e_0KdeCMoR0                presidential tales microsoft office
# 36  aVNfExpzMbI        presidential tales my printer playing music
# 37  Zm2g0RJKWvc    will smith eating spaghetti and meatballs again
# 38  6PoF9Qec52w                          mr bean as poppy deepfake
# 39  _o6eHdkcwwQ      dumb dumber jack black deepfake tiktok shorts
# 40  9_fxI4B3GM0  donald trump as thurman merman in bad santa de...
# 41  IHrlx5Xfwa8             great white sharks roaming the streets
# 42  6EtRrHfeHKc       trump and biden in kindergarten cop deepfake
#
#                                           description  \
# 1   scary ghost cctv footagepatreon copyright is c...
# 2   presidential tales biden trump clinton obama p...
# 4   this video has been created by an ai for exper...
# 8   do not click a help of neural networks anyone ...
# 10  this is an edit from the star wars rise of sky...
# 11  enjoycheck out our community forums helping th...
# 12  do not click a help of neural networks anyone ...
# 14  presidential tales biden trump clinton obama p...
# 15  presidential tales biden trump clinton obama p...
# 26  me when i was 12 wondering what i39d look like...      1     30.09
# 27  donald trump president eeuu rumbo a la preside...      1     40.43
# 30  can39t wait for these 2 traitors to be prosecu...      1     24.80
# 31  wonderful rap take that jack awasome u will be...      1     20.22
# 34  我真的聽不懂英文 the fake lines from ai are too real s...      1     23.48
# 36  gw liked the biden joke the secret service is ...      1     32.67
# 37  026 damn man chris rock better stay away from ...      1     52.87
# 38  unlock the power of stock footage today she39s...      1     17.60
# 39                                                nan      1     14.47
# 40  the kid looks like actor peter gerety from sne...      1     49.06
# 41  bro kept trying to turn into a helicoprion at ...      1     49.62
# 42  unlock the power of stock footage today he loo...      1      9.82
# Size of Cleaned Positive Val Data: 26

# %%
cleaned_pos_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])
cleaned_pos_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])
cleaned_pos_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])

cleaned_pos_test_df['video_id'] = pos_test_df['video_id']
cleaned_pos_test_df['url'] = pos_test_df['url']
cleaned_pos_test_df['label'] = pos_test_df['label']
cleaned_pos_test_df['duration'] = pos_test_df['duration']
cleaned_pos_test_df['title'] = pos_test_df['title'].apply(clean_text)
cleaned_pos_test_df['description'] = pos_test_df['description'].apply(clean_text)
cleaned_pos_test_df['comments'] = pos_test_df['comments'].apply(clean_text)

# %%
display(cleaned_pos_test_df)
print(f'Size of Cleaned Positive Test Data: {len(cleaned_pos_test_df)}')
# Out:
#        video_id                                              title  \
# 1   Xj0vm2n90SU    the hangover chris evans deepfake tiktok shorts
# 2   0M7XvqtWUWc  interview with the vampire robert pattinson de...
# 3   8eMnD0QSZqs  donald trump with mike kathy griffin pence dee...
# 4   Hli_IGInsZc                                    terminator t800
# 5   mC-lE6_MrfI          deepfake sanjay dutt as arnold terminator
# 6   VOBulYr3swc  chloe from detroit become human talks about cr...
# 7   9utpya9UZwU           mr beast and pewdiepie at the playground
# 8   Ktg3uLCcRX8        michael jackson demo private video deepfake
# 12  a15h8twMfqs           dr phil sings dama da ne baka mitai meme
# 13  qCVJprRg3xI                 presidential tales living in china
# 14  zvZHVNLznNI           justin timberlake deepfake tiktok shorts
# 15  tFtw4ukISLk                lionel messi deepfake tiktok shorts
# 16  r0Fs0CoG73M        president donald chunk a true goon deepfake
# 20  26cZgtIrvJk                 presidential tales i asked my date
# 22  ogAFrCpxF7U      presidential tales my doctor told me to drink
# 24  Hyn2RIXgSIM     dirty dancing zac efron deepfake tiktok shorts
# 25  1ONkf23yg2I           presidential tales biden memory problems
# 29  yIzDR8sfVLM              mike tyson tells you to stop deepfake
# 30  RMQPFCyXdvk                           me at the zoo 2 deepfake
# 34  nrOcd9RSekA               presidential tales my doctor told me
# 35  cWoozV6UIc8  vp pence robertson discusses gay adoption deep...
# 37  julqrOsKAvE  trump your enthusiasm ep 1 ft donald trump dee...
# 39  WXeuEHhDPNI                        joker donald trump deepfake
# 40  zVGUr67xwQM  leonardo dicaprio sings godzilla eminem ft jui...
# 43  aX9yw4rfa-w                            pride month paint party
# 44  GR2018v1G4o  keanu reeves as evan baxter steve carell deepf...
# 47  Q0K2GNkSOK0                             yooooo thats the sound
# 49  YKPJ_Jk9C4w                        pop corn starring joe biden
# 7   xdddddddddd nice they looks like disguising al...      1     49.62
# 8                                                 nan      1     15.77
# 12  i love technology bring on the ai overloads th...      1     27.89
# 13  karmala looks like she has had adam39s apple s...      1     28.91
# 14                                                nan      1      8.34
# 15                                                         1     27.24
# 16  ha he would fit on her face a lot better you c...      1     51.69
# 20  i like the don39t don39t “oh thank god” maybe ...      1     25.31
# 22  my mother told me these are so funny joe won t...      1     29.30
# 24                                                nan      1     19.74
# 25  ai for president 2024 putin speaks polish clea...      1     32.07
# 29  unlock the power of stock footage today all dr...      1     11.17
# 30  how did you make the lip sync im sure those cl...      1     18.67
# 34  joe is very smart in the twitter joke love the...      1     31.95
# 35  effort out into this and some idiot comes and ...      1     51.15
# 37  lol and i thought that bald guy is bennie sand...      1     37.83
# 39  unlock the power of stock footage today i supp...      1     25.47
# 40  this is better lip syncing than some motion ca...      1     57.61
# 43  012 wtf is heppening here xddd 044 what there ...      1     48.02
# 44  this is amazing i understand the gibberish par...      1     34.02
# 47                                   023 stiven zigal      1     35.81
# 49  i love this epic cross over the corn pop arc n...      1     56.40
# 50                                                nan      1     12.93
# 51  it actually looks like something i’d dream abo...      1     32.81
# 52                                                nan      1     18.74
# 55  quotlife is like a pequot gorge bush hey yo no...      1     45.93
# 59  i receive communion in my home once a week and...      1     31.51
# 62  hey can you combine this video with joe biden ...      1     48.37
# 63                                                nan      1     14.65
# 64  an ai video where they actually try to eta the...      1     40.01
# 65  whoa he39s very chinese here supporting your c...      1     32.60
# 66  the way this works is that you put a name into...      1     38.41
# 70  footage of ed39s trip to the imperial city all...      1     17.14
# 72  dat zoom tho trump in oblivion link in the des...      1      3.88
# 73                             hello bro after 1 year      1     29.74
# 78                                                nan      1     13.91
# 80  the shark just want to say hi excuse me ，i am ...      1     20.02
# 81  these vids what39s the difference between wild...      1     34.85
# 82                                                nan      1     14.00
# 86  unlock the power of stock footage today noo sh...      1     59.98
# Size of Cleaned Positive Test Data: 46

# %% [markdown]
# ### Cleaning Negatives

# %%
# Create a new DataFrame with the cleaned text for negative
cleaned_neg_train_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])
cleaned_neg_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])
cleand_neg_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])

# %%
cleaned_neg_train_df['video_id'] = neg_train_df['video_id']
cleaned_neg_train_df['url'] = neg_train_df['url']
cleaned_neg_train_df['label'] = neg_train_df['label']
cleaned_neg_train_df['duration'] = neg_train_df['duration']
cleaned_neg_train_df['title'] = neg_train_df['title'].apply(clean_text)
cleaned_neg_train_df['description'] = neg_train_df['description'].apply(clean_text)
cleaned_neg_train_df['comments'] = neg_train_df['comments'].apply(clean_text)

# %%
display(cleaned_neg_train_df)
print(f'Size of Cleaned negative Train Data: {len(cleaned_neg_train_df)}')
# Out:
#         video_id                                              title  \
# 0    NIAnOmqK2k0  yikes joe biden on why he was so irresponsible...
# 3    PNKWjqW8kvI  biden gets confused again middle class didnt b...
# 4    iKKRU3ALjb0        republicans want a national ban on abortion
# 5    N-fELwFvM64        haley ends republican presidential campaign
# 6    r94vuvwUSkY                                          what meme
# ..           ...                                                ...
# 314  TLw64MCra3U   rishi sunak frees up millions of gp appointments
# 315  liII_ikKCIo                                         qui menace
# 316  yyaEuBNhpqY  courteney cox wants zac efron as a love intere...
# 318  rs3vQ49mfrY  im ign keanureeves johnwick redcarpet movies s...
# 320  yJp5bEEO8uo                        elon musk warns as about ai
#
#                                            description  \
# 0                                                  nan
# 3                               comments made on 41724
# 4    follow joejoe’s twitter facebook instagram bid...
# 5    former un ambassador nikki haley ended her bid...
# 6                                         sub and like
# ..                                                 ...
# 314  9 in 10 pharmacies across england are now offe...
# 315                                                nan
# 316  subscribe the place for laughs joy stars surpr...
# 318                                                nan
# 320                                                nan
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=NIAnOmqK2k0
# 3    https://www.youtube.com/watch?v=PNKWjqW8kvI
# 4    https://www.youtube.com/watch?v=iKKRU3ALjb0
# 5    https://www.youtube.com/watch?v=N-fELwFvM64
# 6    https://www.youtube.com/watch?v=r94vuvwUSkY
# ..                                           ...
# 314  https://www.youtube.com/watch?v=TLw64MCra3U
# 315  https://www.youtube.com/watch?v=liII_ikKCIo
# 316  https://www.youtube.com/watch?v=yyaEuBNhpqY
# 318  https://www.youtube.com/watch?v=rs3vQ49mfrY
# 320  https://www.youtube.com/watch?v=yJp5bEEO8uo
#
#                                               comments  label  duration
# 0    idk should i feel sad or mad at him quottheyqu...      0     15.05
# 3    what this is funny but dueable all these illeg...      0      8.71
# 4    fjb he39s to old and his brain doesn39t work k...      0     15.23
# 5    your voice is horrible that congratulations to...      0     44.77
# 6    lol is that russel westbrook 6 sec ad to watch...      0      5.57
# ..                                                 ...    ...       ...
# 314  if i need to see the gp it39s because it39s so...      0     37.96
# 315  p a f p a f monsieur macron pour être un bon p...      0     59.58
# 316  i saw a short video of ellen that was with nev...      0     34.85
# 318  tan bello y humilde they can shoot their way i...      0     16.90
# 320  how is ai possibly more dangerous than nukes i...      0     19.81
#
# [195 rows x 7 columns]
# Size of Cleaned negative Train Data: 195

# %%
cleaned_neg_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])
cleaned_neg_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])
cleaned_neg_val_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])

cleaned_neg_val_df['video_id'] = neg_val_df['video_id']
cleaned_neg_val_df['url'] = neg_val_df['url']
cleaned_neg_val_df['label'] = neg_val_df['label']
cleaned_neg_val_df['duration'] = neg_val_df['duration']
cleaned_neg_val_df['title'] = neg_val_df['title'].apply(clean_text)
cleaned_neg_val_df['description'] = neg_val_df['description'].apply(clean_text)
cleaned_neg_val_df['comments'] = neg_val_df['comments'].apply(clean_text)

# %%
display(cleaned_neg_val_df)
print(f'Size of Cleaned negative Val Data: {len(cleaned_neg_val_df)}')
# Out:
#        video_id                                              title  \
# 2   xzm_IlrpK_Y  ראש הממשלה נתניהו במערך 9900 אנחנו אומרים למחב...
# 3   R1DaTvQXwpY  impeached dhs sec alejandro mayorkas the south...
# 5   _I9vGD4j1_U  breaking joe biden says one of the classified ...
# 6   s_zva6pf3oA          donald trump predicts his victory in 1988
# 8   YIWdxO2J-Tw    the top 5 moments of taylor swift’s life shorts
# 10  527-1MrJYUE  laxmi raai spotted at kromakay salon in juhu l...
# 15  DKB4Mf5PVFY  trump being a sigma… alphamale masculinity fun...
# 16  wswxrDiSiHI  obamas quick response to sarcastic republican ...
# 17  whnY9-ugr2w  trump sells bibles after years of touting his ...
# 28  https://www.youtube.com/watch?v=p1WD_rDHsFc
# 29  https://www.youtube.com/watch?v=xudVnd6DTSQ
# 30  https://www.youtube.com/watch?v=B4K_OfMnTD0
# 33  https://www.youtube.com/watch?v=caqsDWJ-q8c
# 35  https://www.youtube.com/watch?v=PgJ_R1gjwTs
# 39  https://www.youtube.com/watch?v=F8ajpQV-Fb4
# 42  https://www.youtube.com/watch?v=3KgGuOYUylE
# 43  https://www.youtube.com/watch?v=3vO1eXoRvUg
# 44  https://www.youtube.com/watch?v=tZOT-HzZy-Y
# 45  https://www.youtube.com/watch?v=1nW1S46_B-Y
#
#                                              comments  label  duration
# 2   أبو عبيدة الرايق باقي ماشفنا منك حتى شيكل باش ...      0     25.38
# 3   more hot air genital head is lying sure seems ...      0     44.14
# 5   why isn39t he arrested for treason put him in ...      0     26.45
# 6   and he is one of those making fools fool trump...      0     24.09
# 8   i taylor swift they weren39t talking about fel...      0     59.16
# 10  aunty i love you beautiful en logo ko ur koi k...      0     54.61
# 15  men had enough exit the and last… don’t be a l...      0     16.90
# 16  votor fraudulent wins isis and 65k dollars of ...      0     24.96
# 17  trump shampoo what a joke why didn’t he just t...      0     59.88
# 18  wow his analogy and wording comes off as hurtf...      0     33.95
# 20  sarcasm is a dangerous thing when there’s dish...      0     38.85
# 21  you great destroyed america and americans peop...      0      8.01
# 22  the best funny moment you absolutely have to s...      0     59.40
# 23  casting couch on xvideos wow she is really cut...      0     48.27
# 25  rahul gandhi jindabad sir aap bahut great ho a...      0     41.33
# 26  filmes de gora novela agora mi gran admiración...      0     45.14
# 28  those flashy looks are perfect for sg to portr...      0     40.26
# 29  keep working and speaking mr president joe bid...      0     15.63
# 30  joe biden is destroying america fjb thank you ...      0     56.63
# 33  nananan brooooooo the sound effects i would be...      0     56.29
# 35  movie name baar baar kapil sharma ke show me j...      0     14.14
# 39  fluffy haaaaaaa i love your videos hands down ...      0     35.13
# 42  yes god bless elon musk no he did not win it w...      0     59.47
# 43  shame shame shame may god open his heart to th...      0     55.01
# 44  what kind of a mom are you that don39t show yo...      0     35.25
# 45                                                nan      0     26.45
# Size of Cleaned negative Val Data: 26

# %%
cleaned_neg_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])
cleaned_neg_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])
cleaned_neg_test_df = pd.DataFrame(columns=['video_id', 'title', 'description', 'url', 'comments', 'label', 'duration'])

cleaned_neg_test_df['video_id'] = neg_test_df['video_id']
cleaned_neg_test_df['url'] = neg_test_df['url']
cleaned_neg_test_df['label'] = neg_test_df['label']
cleaned_neg_test_df['duration'] = neg_test_df['duration']
cleaned_neg_test_df['title'] = neg_test_df['title'].apply(clean_text)
cleaned_neg_test_df['description'] = neg_test_df['description'].apply(clean_text)
cleaned_neg_test_df['comments'] = neg_test_df['comments'].apply(clean_text)

# %%
display(cleaned_neg_test_df)
print(f'Size of Cleaned negative Test Data: {len(cleaned_neg_test_df)}')
# Out:
#        video_id                                              title  \
# 0   xAPIjhkXF-0         tom cruise gives the most epic answer ever
# 3   zOh1-WHonds  shehnaaz kaur gill at lakme fashion week shehn...
# 4   zotkJwZ9PVY                             these are young adults
# 5   JZV3aZfextU                                       come with me
# 7   xdbvjb9-fpg                          i wish i was exaggerating
# 35  same level of legend than chaplin and keaton c...      0     49.47
# 39  joe biden 2024 arent you blue joe ancora non c...      0     33.83
# 40  trump 2024 that was in iraq as long as trump g...      0     49.81
# 41  ትራንፕ እግዚአብሔር ያሳርፍ ምድርቷ ወደ እረፍቷ የምትመጣበት ቀን ደርሶዋ...      0     30.72
# 44  free palestine you coward reside with neighbou...      0     33.74
# 47  very sad i hope they did39nt suffer to the fam...      0     59.84
# 48  you can literally see the agenda in her eyes t...      0     30.67
# 49  что это с ним было put that freedom down now s...      0      4.18
# 51  haah haaah bahi saans lelo thoda kuch bhi ho j...      0     17.58
# 52                                                nan      0     55.10
# 53  i love you kevin hart let him explain kevin wh...      0     55.64
# 54  americans what a joke putin looks like he coul...      0     34.25
# 56                                                nan      0     49.09
# 57  very nice short video ellen omg where can i ge...      0     59.56
# 59                                                nan      0     51.94
# 60  there is no israeal only palestine shame on am...      0     43.86
# 61  so because there’s a lot of killers that makes...      0     23.96
# 62  oooh la laaaaaa lol sully didn’t understand th...      0      6.92
# 66  says the hypocrite crook well we don39t have t...      0     38.01
# 68  putin doing putin things let it go what he doe...      0     33.11
# 69                jay shree ram kya bola zbrdast nice      0     16.37
# 70  never miss out on ai trends that could quickly...      0     58.89
# 71  the more i watch the more understanding he thi...      0     54.52
# 72  brilliant he is perfect blend of intelligence ...      0     28.00
# 75  can39t do his job right keep working and speak...      0     52.64
# 77  llist mysore cafe in stock market our people t...      0     24.64
# 81  27 times two face i like him the best presiden...      0     59.95
# 83  “not this year” bro sounded like batman trump ...      0     23.96
# 90  like and share the video if you love president...      0     39.33
# 91  youtube why are you paranoid of my comments do...      0     24.20
# Size of Cleaned negative Test Data: 51

# %% [markdown]
# ### Change 'nan' to NaN

# %%
cleaned_neg_train_df = cleaned_neg_train_df.replace('nan', np.nan)
cleaned_neg_val_df = cleaned_neg_val_df.replace('nan', np.nan)
cleaned_neg_test_df = cleaned_neg_test_df.replace('nan', np.nan)

cleaned_pos_train_df = cleaned_pos_train_df.replace('nan', np.nan)
cleaned_pos_val_df = cleaned_pos_val_df.replace('nan', np.nan)
cleaned_pos_test_df = cleaned_pos_test_df.replace('nan', np.nan)

# %%
cleaned_neg_train_df
# Out:
#         video_id                                              title  \
# 0    NIAnOmqK2k0  yikes joe biden on why he was so irresponsible...
# 3    PNKWjqW8kvI  biden gets confused again middle class didnt b...
# 4    iKKRU3ALjb0        republicans want a national ban on abortion
# 5    N-fELwFvM64        haley ends republican presidential campaign
# 6    r94vuvwUSkY                                          what meme
# ..           ...                                                ...
# 314  TLw64MCra3U   rishi sunak frees up millions of gp appointments
# 315  liII_ikKCIo                                         qui menace
# 316  yyaEuBNhpqY  courteney cox wants zac efron as a love intere...
# 318  rs3vQ49mfrY  im ign keanureeves johnwick redcarpet movies s...
# 320  yJp5bEEO8uo                        elon musk warns as about ai
#
#                                            description  \
# 0                                                  NaN
# 3                               comments made on 41724
# 4    follow joejoe’s twitter facebook instagram bid...
# 5    former un ambassador nikki haley ended her bid...
# 6                                         sub and like
# ..                                                 ...
# 314  9 in 10 pharmacies across england are now offe...
# 315                                                NaN
# 316  subscribe the place for laughs joy stars surpr...
# 318                                                NaN
# 320                                                NaN
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=NIAnOmqK2k0
# 3    https://www.youtube.com/watch?v=PNKWjqW8kvI
# 4    https://www.youtube.com/watch?v=iKKRU3ALjb0
# 5    https://www.youtube.com/watch?v=N-fELwFvM64
# 6    https://www.youtube.com/watch?v=r94vuvwUSkY
# ..                                           ...
# 314  https://www.youtube.com/watch?v=TLw64MCra3U
# 315  https://www.youtube.com/watch?v=liII_ikKCIo
# 316  https://www.youtube.com/watch?v=yyaEuBNhpqY
# 318  https://www.youtube.com/watch?v=rs3vQ49mfrY
# 320  https://www.youtube.com/watch?v=yJp5bEEO8uo
#
#                                               comments  label  duration
# 0    idk should i feel sad or mad at him quottheyqu...      0     15.05
# 3    what this is funny but dueable all these illeg...      0      8.71
# 4    fjb he39s to old and his brain doesn39t work k...      0     15.23
# 5    your voice is horrible that congratulations to...      0     44.77
# 6    lol is that russel westbrook 6 sec ad to watch...      0      5.57
# ..                                                 ...    ...       ...
# 314  if i need to see the gp it39s because it39s so...      0     37.96
# 315  p a f p a f monsieur macron pour être un bon p...      0     59.58
# 316  i saw a short video of ellen that was with nev...      0     34.85
# 318  tan bello y humilde they can shoot their way i...      0     16.90
# 320  how is ai possibly more dangerous than nukes i...      0     19.81
#
# [195 rows x 7 columns]

# %%
cleaned_neg_val_df
# Out:
#        video_id                                              title  \
# 2   xzm_IlrpK_Y  ראש הממשלה נתניהו במערך 9900 אנחנו אומרים למחב...
# 3   R1DaTvQXwpY  impeached dhs sec alejandro mayorkas the south...
# 5   _I9vGD4j1_U  breaking joe biden says one of the classified ...
# 6   s_zva6pf3oA          donald trump predicts his victory in 1988
# 8   YIWdxO2J-Tw    the top 5 moments of taylor swift’s life shorts
# 10  527-1MrJYUE  laxmi raai spotted at kromakay salon in juhu l...
# 15  DKB4Mf5PVFY  trump being a sigma… alphamale masculinity fun...
# 16  wswxrDiSiHI  obamas quick response to sarcastic republican ...
# 17  whnY9-ugr2w  trump sells bibles after years of touting his ...
# 18  t7xDb82TqiI              nvidias ceo on greatness jensen huang
# 20  TghKVxflpYo               donald trump impression of joe biden
# 21  s6Wjo9Civ_k  joe biden reading from his giant teleprompter ...
# 22  LYZTKTRLZ2U  rowan atkinson funny moments at top gear bbc t...
# 23  TivAwezqug4                            anushka sharma audition
# 25  1iBI3uW6lJA  i made this video last night at 1230am but my ...
# 26  vxOzffnZ-Ds  selena gomez on being a fashion newbie met gal...
# 28  p1WD_rDHsFc     selena gomez goes behind the scenes with vogue
# 29  xudVnd6DTSQ                         democracy is on the ballot
# 30  B4K_OfMnTD0  kennedy family endorses pres biden in 2024 ele...
# 33  caqsDWJ-q8c                      snoop dogg was looking for me
# 35  PgJ_R1gjwTs  akshay kumar cant spell jacquelines name funny...
# 39  F8ajpQV-Fb4                  only have chicos to end the night
# 42  3KgGuOYUylE                         elon musk roasts joe biden
# 43  3vO1eXoRvUg              norman finkelstein reason of iraq war
# 83  “not this year” bro sounded like batman trump ...      0     23.96
# 90  like and share the video if you love president...      0     39.33
# 91  youtube why are you paranoid of my comments do...      0     24.20

# %% [markdown]
# ### Unsupervised Approaches to Generate Comments

# %% [markdown]
# #### Use Topic Modeling to Generate Comments for NaN comments

# %%
def topic_modeling_synthetic_comments(cleaned_df = None):
    # assuming 'comments' column is already preprocessed
    vectorizer = CountVectorizer(stop_words='english')
    doc_term_matrix = vectorizer.fit_transform(cleaned_df['comments'].dropna())

    # Train the LDA topic model
    lda_model = LatentDirichletAllocation(n_components=10, random_state=42)
    lda_model.fit(doc_term_matrix)

    # Generate synthetic comments for videos without comments
    for index, row in cleaned_df[cleaned_df['comments'].isna()].iterrows():
        video_label = row['label']
        video_title = row['title']
        video_description = row['description']  # Assuming 'description' column contains video descriptions
        
        # Combine video title and description
        video_metadata = f"{video_title} {video_description}"
        
        # Predict the topic distribution for the video
        topic_prob = lda_model.transform(vectorizer.transform([video_metadata]))[0]
        top_topics = topic_prob.argsort()[-3:][::-1]
        
        # Generate synthetic comments
        synthetic_comment = []
        for topic_id in top_topics:
            top_words = [vectorizer.get_feature_names_out()[i] for i in lda_model.components_[topic_id].argsort()[-5:][::-1]]
            synthetic_comment.extend(top_words)
        
        synthetic_comment = ' '.join(synthetic_comment)
        cleaned_df.at[index, 'comments'] = synthetic_comment

# %% [markdown]
# #### Use Sentiment Analysis

# %%
def sentiment_analysis_synthetic_comments(cleaned_df=None):

    # assuming 'comments' column is already preprocessed
    vectorizer = TfidfVectorizer()
    comment_matrix = vectorizer.fit_transform(cleaned_df['comments'].dropna())

    # Perform sentiment analysis on the available comments
    sentiment_scores = []
    for comment in cleaned_df['comments'].dropna():
        sentiment = TextBlob(comment).sentiment.polarity
        sentiment_scores.append(sentiment)

    cleaned_df['sentiment'] = pd.Series(sentiment_scores)

    # Generate synthetic comments for videos without comments
    for index, row in cleaned_df[cleaned_df['comments'].isna()].iterrows():
        video_label = row['label']
        video_title = row['title']
        video_description = row['description']
        
        # Combine video title and description
        video_metadata = f"{video_title} {video_description}"
        
        # Find similar videos based on video metadata
        metadata_vector = vectorizer.transform([video_metadata])
        similarity_scores = cosine_similarity(metadata_vector, comment_matrix)
        similar_indices = similarity_scores.argsort()[0][-5:][::-1]
        
        # Get the sentiment scores of similar videos
        similar_sentiments = cleaned_df.iloc[similar_indices]['sentiment']
        
        # Determine the sentiment for the video based on similar videos and its label
        if video_label == 1:  # Deepfake video
            sentiment = similar_sentiments.min()
        else:  # Non-deepfake video
            sentiment = similar_sentiments.max()
        
        # Generate synthetic comment based on sentiment and video characteristics
        if sentiment > 0:
            synthetic_comment = f"This video about {video_title} seems interesting. {video_description}"
        elif sentiment < 0:
            synthetic_comment = f"I'm not sure about the content of this video on {video_title}. {video_description}"
        else:
            synthetic_comment = f"The video '{video_title}' discusses {video_description}."
        
        cleaned_df.at[index, 'comments'] = synthetic_comment

# %% [markdown]
# #### Collaborative Filtering

# %%
def collab_filter_synth_comments(cleaned_df=None):

    # assuming 'comments' column is already preprocessed
    vectorizer = TfidfVectorizer()
    comment_matrix = vectorizer.fit_transform(cleaned_df['comments'].dropna())

    # Perform dimensionality reduction using Truncated SVD
    svd = TruncatedSVD(n_components=100)
    reduced_matrix = svd.fit_transform(comment_matrix)

    # Generate synthetic comments for videos without comments
    for index, row in cleaned_df[cleaned_df['comments'].isna()].iterrows():
        video_label = row['label']
        video_title = row['title']
        video_description = row['description']
        
        # Combine video title and description
        video_metadata = f"{video_title} {video_description}"
        
        # Find similar videos based on video metadata
        metadata_vector = vectorizer.transform([video_metadata])
        reduced_metadata_vector = svd.transform(metadata_vector)
        similarity_scores = cosine_similarity(reduced_metadata_vector, reduced_matrix)
        similar_indices = similarity_scores.argsort()[0][-5:][::-1]
        
        # Get the comments from similar videos
        similar_comments = cleaned_df.iloc[similar_indices]['comments']
        
        # Filter out missing comments
        valid_comments = similar_comments.dropna()
        
        # Generate synthetic comment by combining valid comments from similar videos
        if not valid_comments.empty:
            synthetic_comment = ' '.join(valid_comments)
        else:
            synthetic_comment = "No relevant comments found."
        
        cleaned_df.at[index, 'comments'] = synthetic_comment

# %%
collab_filter_synth_comments(cleaned_neg_train_df)
collab_filter_synth_comments(cleaned_neg_val_df)
collab_filter_synth_comments(cleaned_neg_test_df)

collab_filter_synth_comments(cleaned_pos_train_df)
collab_filter_synth_comments(cleaned_pos_val_df)
collab_filter_synth_comments(cleaned_pos_test_df)

# %%
print('Negatives:')
nan_count = cleaned_neg_train_df['comments'].isna().sum()
print(f'Number of NaN in cleaned_neg_train_df: {nan_count}')

nan_count = cleaned_neg_val_df['comments'].isna().sum()
print(f'Number of NaN in cleaned_neg_val_df: {nan_count}')

nan_count = cleaned_neg_test_df['comments'].isna().sum()
print(f'Number of NaN in cleaned_neg_test_df: {nan_count}')

print('\nPositives:')
nan_count = cleaned_pos_train_df['comments'].isna().sum()
print(f'Number of NaN in cleaned_pos_train_df: {nan_count}')

nan_count = cleaned_pos_val_df['comments'].isna().sum()
print(f'Number of NaN in cleaned_pos_val_df: {nan_count}')

nan_count = cleaned_pos_test_df['comments'].isna().sum()
print(f'Number of NaN in cleaned_pos_test_df: {nan_count}')
# Out:
# Negatives:
# Number of NaN in cleaned_neg_train_df: 0
# Number of NaN in cleaned_neg_val_df: 0
# Number of NaN in cleaned_neg_test_df: 0
#
# Positives:
# Number of NaN in cleaned_pos_train_df: 0
# Number of NaN in cleaned_pos_val_df: 0
# Number of NaN in cleaned_pos_test_df: 0

# %% [markdown]
# ### Consolidate the Data

# %%
# create training set
train_df = pd.concat([cleaned_pos_train_df, cleaned_neg_train_df])
# create validation set
val_df = pd.concat([cleaned_pos_val_df, cleaned_neg_val_df])
# create test set
test_df = pd.concat([cleaned_pos_test_df, cleaned_neg_test_df])

# %%
# training set
num_pos_train = len(cleaned_pos_train_df)
num_neg_train = len(cleaned_neg_train_df)
num_train = len(train_df)
print(f'Expected Size of Training set: {num_neg_train + num_pos_train}')
print(f'Actual Size of Training Set: {num_train}')
# Out:
# Expected Size of Training set: 371
# Actual Size of Training Set: 371

# %%
# validation set
num_pos_val = len(cleaned_pos_val_df)
num_neg_val = len(cleaned_neg_val_df)
num_val = len(val_df)
print(f'Expected Size of Validation set: {num_pos_val + num_neg_val}')
print(f'Actual Size of Validation Set: {num_val}')
# Out:
# Expected Size of Validation set: 52
# Actual Size of Validation Set: 52

# %%
# test set
num_pos_test = len(cleaned_pos_test_df)
num_neg_test = len(cleaned_neg_test_df)
num_test = len(test_df)
print(f'Expected Size of Test set: {num_pos_test + num_neg_test}')
print(f'Actual Size of Test Set: {num_test}')
# Out:
# Expected Size of Test set: 97
# Actual Size of Test Set: 97

# %% [markdown]
# ### Move Training data to file

# %%
def delete_folder_contents(path):
    for filename in os.listdir(path):
        file_path = os.path.join(path, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)  # Remove file or link
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)  # Remove directory and all its contents
        except Exception as e:
            print(f'Failed to delete {file_path}. Reason: {e}')

# %%
delete_folder_contents(train_dir)
delete_folder_contents(val_dir)
delete_folder_contents(test_dir)

# %%
def move_videos(src_dir, dest_dir, df):

    failed = list()

    # Create the "train" directory if it doesn't exist
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    # Iterate over each row in the DataFrame
    for _, row in df.iterrows():
        video_id = row['video_id']
        
        # Construct the source and destination file paths
        source_path = os.path.join(src_dir, f"{video_id}.mp4")
        destination_path = os.path.join(dest_dir, f"{video_id}.mp4")
        
        # Check if the source video file exists
        if os.path.exists(source_path):
            # Copy the video file from the source to the destination
            shutil.copy2(source_path, destination_path)
            # print(f"Copied video {video_id}.mp4 to train directory.")
        else:
            print(f"Video {video_id}.mp4 not found in {src_dir} directory.")
            failed.append(video_id)

    if(len(failed) > 0):
        print(f'The following videos were not copied from {src_dir} to {dest_dir}')
        for vid in failed:
            print(vid)

# %%
# move pos training videos in train
# move_videos(src_dir=pos_dir, dest_dir=train_dir, df=cleaned_pos_df)

# %%
# move neg training videos into train
# move_videos(src_dir=neg_dir, dest_dir=train_dir, df=cleaned_neg_df)

# %%
def copy_videos(df, dest_dir):

    failed = list()

    # Create the "train" directory if it doesn't exist
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir)

    # Iterate over each row in the DataFrame
    for _, row in df.iterrows():
        video_id = row['video_id']
        label = row['label']

        src_dir = None

        if label == 1:
            src_dir = pos_vids_dir
        else:
            src_dir = neg_vids_dir
        
        # Construct the source and destination file paths
        source_path = os.path.join(src_dir, f"{video_id}.mp4")
        destination_path = os.path.join(dest_dir, f"{video_id}.mp4")

        # Check if the source video file exists
        if os.path.exists(source_path):
            # Copy the video file from the source to the destination
            shutil.copy2(source_path, destination_path)
            # print(f"Copied video {video_id}.mp4 to train directory.")
        else:
            print(f"Video {video_id}.mp4 not found in {src_dir} directory.")
            failed.append(video_id)

    if(len(failed) > 0):
        print(f'The following videos were not copied from {src_dir} to {dest_dir}')
        for vid in failed:
            print(vid)

# %%
copy_videos(df=train_df, dest_dir=train_dir)
print(f'Number of files in train_df: {num_train}')
print(f'NUmber of files copies to Train Dir: {len(os.listdir(train_dir))}')
# Out:
# Number of files in train_df: 371
# NUmber of files copies to Train Dir: 371

# %%
# Finding duplicates in column 'A'
# duplicates = train_df.duplicated('video_id', keep=False)  # 'keep=False' marks all duplicates as True
# duplicated_train = train_df[duplicates]
# duplicated_train

# %%
# # Identify duplicated video_id entries
# duplicates = train_df.duplicated('video_id', keep=False)

# # Create a DataFrame with only the duplicated entries
# duplicated_train = train_df[duplicates]

# # Count the unique video_ids that have duplicates
# unique_duplicates_count = duplicated_train['video_id'].nunique()

# # Output the count of unique duplicate video_ids
# print(f'Number of unique video_ids that are duplicated: {unique_duplicates_count}')

# # Now print the number of files in train_df and the number of files copied to Train Dir
# print(f'Number of files in train_df: {len(train_df)}')
# print(f'Number of files copied to Train Dir: {len(os.listdir(train_dir))}')

# # Calculate the difference
# num_files_discrepancy = len(train_df) - len(os.listdir(train_dir))

# # Check if the number of unique duplicates matches the discrepancy
# if num_files_discrepancy == unique_duplicates_count:
#     print("The discrepancy matches the number of unique duplicate video_ids.")
# else:
#     print("There is an inconsistency in the number of duplicates.")

# %%
copy_videos(df=val_df, dest_dir=val_dir)
print(f'Number of files in val_df: {num_val}')
print(f'NUmber of files copies to Val Dir: {len(os.listdir(val_dir))}')
# Out:
# Number of files in val_df: 52
# NUmber of files copies to Val Dir: 52

# %%
copy_videos(df=test_df, dest_dir=test_dir)
print(f'Number of files in test_df: {num_test}')
print(f'NUmber of files copies to Test Dir: {len(os.listdir(test_dir))}')
# Out:
# Number of files in test_df: 97
# NUmber of files copies to Test Dir: 97

# %%
# Get the list of video files in the "train/val/test" directory
def validateCopy(df=None, dir_type=None, copyDir=None):

    videos = [f for f in os.listdir(copyDir) if f.endswith(".mp4")]

    # Extract the video IDs from the filenames in the "train" directory
    video_ids = [os.path.splitext(f)[0] for f in videos]

    # Get the video IDs from the DataFrame
    all_video_ids = df['video_id']

    # Find the missing video IDs
    missing_video_ids = all_video_ids.loc[~all_video_ids.isin(video_ids)]

    # Print the missing video IDs
    if len(missing_video_ids) > 0:
        print("Missing videos:")
        for video_id in missing_video_ids:
            print(video_id)
    else:
        print(f'All {dir_type} videos were successfully copied.')

# %%
# check train videos
validateCopy(df=train_df, dir_type='training', copyDir=train_dir)
# check val videos
validateCopy(df=val_df, dir_type='validation', copyDir=val_dir)
# check test videos
validateCopy(df=test_df, dir_type='test', copyDir=test_dir)
# Out:
# All training videos were successfully copied.
# All validation videos were successfully copied.
# All test videos were successfully copied.

# %%
# # Find common video IDs using intersection()
# common_video_ids = set(cleaned_pos_df['video_id']).intersection(set(cleaned_neg_df['video_id']))

# # Print the common video IDs
# if len(common_video_ids) > 0:
#     print("Common video IDs:")
#     for video_id in common_video_ids:
#         print(video_id)
# else:
#     print("No common video IDs found.")

# %% [markdown]
# ### Create Annotation Files

# %%
annotations_dir = '../annotations'

video_train = 'video_train.csv'
video_val = 'video_val.csv'
video_test = 'video_test.csv'

text_train = 'text_train.csv'
text_val = 'text_val.csv'
text_test = 'text_test.csv'

# %% [markdown]
# #### Remove existing annotation files

# %%
delete_folder_contents(annotations_dir)

# %% [markdown]
# #### Video files path annotations

# %%
def create_video_path_df(prefix, suffix, df, root_dir, output_file):

    # concatenating prefix, video_id from train_df, and suffix
    new_df = pd.DataFrame()
    new_df['video_path'] = prefix + df['video_id'].astype(str) + suffix
    new_df['label'] = df['label']
    
    # Write the DataFrame to a CSV file
    output_file_path = os.path.join(root_dir, output_file)
    new_df.to_csv(output_file_path, index=False)
    print(f"CSV file has been created at: {output_file_path}")

# %%
train_prefix = './train/'
val_prefix = './val/'
test_prefix = './test/'
suffix = ".mp4"

# %%
create_video_path_df(prefix=train_prefix, suffix=suffix, df=train_df, root_dir=annotations_dir, output_file='video_train_path.csv')
create_video_path_df(prefix=val_prefix, suffix=suffix, df=val_df, root_dir=annotations_dir, output_file='video_val_path.csv')
create_video_path_df(prefix=test_prefix, suffix=suffix, df=test_df, root_dir=annotations_dir, output_file='video_test_path.csv')
# Out:
# CSV file has been created at: ../annotations/video_train_path.csv
# CSV file has been created at: ../annotations/video_val_path.csv
# CSV file has been created at: ../annotations/video_test_path.csv

# %%
train_annotation = pd.read_csv('../annotations/video_train_path.csv')
type(train_annotation.iloc[0]['video_path'])
# Out:
# str

# %% [markdown]
# #### Video and Text csv file with labels

# %%
def create_video_csv(df, root_dir, output_file):

    new_df = pd.DataFrame()
    new_df['video_id'] = df['video_id']
    new_df['label'] = df['label']

    # Write the DataFrame to a CSV file
    output_file_path = os.path.join(root_dir, output_file)
    new_df.to_csv(output_file_path, index=False)
    print(f"CSV file has been created at: {output_file_path}")

# %%
def create_text_csv(df, root_dir, output_file):

    new_df = pd.DataFrame()
    new_df['text'] = df['comments']
    new_df['label'] = df['label']

    # Write the DataFrame to a CSV file
    output_file_path = os.path.join(root_dir, output_file)
    new_df.to_csv(output_file_path, index=False)
    print(f"CSV file has been created at: {output_file_path}")

# %%
create_video_csv(train_df, annotations_dir, video_train)
create_video_csv(val_df, annotations_dir, video_val)
create_video_csv(test_df, annotations_dir, video_test)

create_text_csv(train_df, annotations_dir, text_train)
create_text_csv(val_df, annotations_dir, text_val)
create_text_csv(test_df, annotations_dir, text_test)
# Out:
# CSV file has been created at: ../annotations/video_train.csv
# CSV file has been created at: ../annotations/video_val.csv
# CSV file has been created at: ../annotations/video_test.csv
# CSV file has been created at: ../annotations/text_train.csv
# CSV file has been created at: ../annotations/text_val.csv
# CSV file has been created at: ../annotations/text_test.csv

# %%
video_train_annotation = pd.read_csv(os.path.join(annotations_dir, video_train))
text_train_annotation = pd.read_csv(os.path.join(annotations_dir, text_train))

# %%
video_train_annotation
# Out:
#         video_id  label
# 0    KabnUV5luJ8      1
# 1    6aSoP0mDM0g      1
# 2    H_RFyF-tgZ4      1
# 3    E_hjqpXgUO0      1
# 4    pQuS5Pmrtnk      1
# ..           ...    ...
# 366  TLw64MCra3U      0
# 367  liII_ikKCIo      0
# 368  yyaEuBNhpqY      0
# 369  rs3vQ49mfrY      0
# 370  yJp5bEEO8uo      0
#
# [371 rows x 2 columns]

# %%
text_train_annotation
# Out:
#                                                   text  label
# 0    please name of the software deep fake try putt...      1
# 1    now we need trumps card to block the attacks a...      1
# 2    how do you guys not have millions of subscribe...      1
# 3                      same lol the way the head moves      1
# 4    unlock the power of stock footage today nathan...      1
# ..                                                 ...    ...
# 366  if i need to see the gp it39s because it39s so...      0
# 367  p a f p a f monsieur macron pour être un bon p...      0
# 368  i saw a short video of ellen that was with nev...      0
# 369  tan bello y humilde they can shoot their way i...      0
# 370  how is ai possibly more dangerous than nukes i...      0
#
# [371 rows x 2 columns]
